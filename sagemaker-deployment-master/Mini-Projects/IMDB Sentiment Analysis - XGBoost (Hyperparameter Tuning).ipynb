# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2020-04-19 23:04:15--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  22.6MB/s    in 5.1s
#
# 2020-04-19 23:04:21 (15.7 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'I thought I should qualify my position after reading other reviews. The movie is not great, but it has a lot of great elements. The lighting and scenes along with the camera work are great. The story is slow and weak, but entertaining. The acting is bad, but no worse than you will find on the SyFy Channel. The music is pretty good and the gore is good. It has the great Leather Face in the film and is produced by Bruce Campbell. I watched the complete movie and while mostly predictable, it was still enjoyable. The women are attractive enough and the lead actor does a good job of being brooding and creepy. The movie was remarkably clean for a modern film and the violence appropriate for children 13 and up. There was no sex scenes. I gave it 7 out of 10 and I think that is fair. I would watch it again if I had nothing better to do. The gay sounding angel was the most annoying aspect of the film, the devil is quite creepy.'

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator.attach("xgboost-2020-04-19-22-48-49-285")

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
# Out:
# 2020-04-19 22:56:42 Starting - Preparing the instances for training
# 2020-04-19 22:56:42 Downloading - Downloading input data
# 2020-04-19 22:56:42 Training - Training image download completed. Training in progress.
# 2020-04-19 22:56:42 Uploading - Uploading generated training model
# 2020-04-19 22:56:42 Completed - Training job completedArguments: train
# [2020-04-19:22:51:17:INFO] Running standalone xgboost training.
# [2020-04-19:22:51:17:INFO] File size need to be processed in the node: 238.5mb. Available memory size in the node: 8502.34mb
# [2020-04-19:22:51:17:INFO] Determined delimiter of CSV input is ','
# [22:51:17] S3DistributionType set as FullyReplicated
# [22:51:19] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-04-19:22:51:19:INFO] Determined delimiter of CSV input is ','
# [22:51:19] S3DistributionType set as FullyReplicated
# [22:51:20] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:51:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=5
# [0]#011train-error:0.3054#011validation-error:0.3125
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
#
# Will train until validation-error hasn't improved in 10 rounds.
# [22:51:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=5
# [1]#011train-error:0.291#011validation-error:0.2992
# [22:51:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 10 pruned nodes, max_depth=5
# [2]#011train-error:0.273533#011validation-error:0.2833
# [22:51:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 14 pruned nodes, max_depth=5
# [3]#011train-error:0.264333#011validation-error:0.2756
# [22:51:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=5
# [4]#011train-error:0.2662#011validation-error:0.2809
# [22:51:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [5]#011train-error:0.257333#011validation-error:0.2722
# [22:51:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [6]#011train-error:0.2478#011validation-error:0.2621
# [22:51:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [7]#011train-error:0.2406#011validation-error:0.2573
# [22:51:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [8]#011train-error:0.235067#011validation-error:0.2504
# [22:51:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=5
# [9]#011train-error:0.229133#011validation-error:0.2481
# [22:51:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=5
# [10]#011train-error:0.2252#011validation-error:0.2449
# [22:51:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [11]#011train-error:0.22#011validation-error:0.2397
# [22:51:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [12]#011train-error:0.212533#011validation-error:0.2332
# [22:51:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=5
# [13]#011train-error:0.211267#011validation-error:0.2292
# [22:51:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [14]#011train-error:0.206133#011validation-error:0.2273
# [22:51:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [15]#011train-error:0.2026#011validation-error:0.2252
# [22:51:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [16]#011train-error:0.200067#011validation-error:0.2229
# [22:51:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [17]#011train-error:0.196933#011validation-error:0.2213
# [22:51:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [18]#011train-error:0.194933#011validation-error:0.2186
# [22:51:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=5
# [19]#011train-error:0.190267#011validation-error:0.2163
# [22:51:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [20]#011train-error:0.1884#011validation-error:0.2124
# [22:51:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [21]#011train-error:0.1844#011validation-error:0.2094
# [22:51:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 8 pruned nodes, max_depth=5
# [22]#011train-error:0.181333#011validation-error:0.2077
# [22:51:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=5
# [23]#011train-error:0.176467#011validation-error:0.2062
# [22:51:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [24]#011train-error:0.1746#011validation-error:0.2063
# [22:51:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [25]#011train-error:0.173133#011validation-error:0.2047
# [22:51:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [26]#011train-error:0.170867#011validation-error:0.2035
# [22:51:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [27]#011train-error:0.169133#011validation-error:0.2024
# [22:51:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [28]#011train-error:0.168#011validation-error:0.2008
# [22:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [29]#011train-error:0.166467#011validation-error:0.1979
# [22:52:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [30]#011train-error:0.164467#011validation-error:0.1978
# [22:52:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [31]#011train-error:0.163933#011validation-error:0.1968
# [22:52:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [32]#011train-error:0.1626#011validation-error:0.1959
# [22:52:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [33]#011train-error:0.1608#011validation-error:0.1957
# [22:52:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=5
# [34]#011train-error:0.1598#011validation-error:0.1951
# [22:52:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [35]#011train-error:0.159067#011validation-error:0.1935
# [22:52:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [36]#011train-error:0.1564#011validation-error:0.1912
# [22:52:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [37]#011train-error:0.1548#011validation-error:0.1897
# [22:52:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [38]#011train-error:0.152#011validation-error:0.1881
# [22:52:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=5
# [39]#011train-error:0.1492#011validation-error:0.1865
# [22:52:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [40]#011train-error:0.147133#011validation-error:0.1858
# [22:52:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [41]#011train-error:0.147067#011validation-error:0.184
# [22:52:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [42]#011train-error:0.145867#011validation-error:0.1841
# [22:52:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [43]#011train-error:0.143733#011validation-error:0.1822
# [22:52:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [44]#011train-error:0.142667#011validation-error:0.1824
# [22:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [45]#011train-error:0.1412#011validation-error:0.1813
# [22:52:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [46]#011train-error:0.1404#011validation-error:0.1795
# [22:52:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [47]#011train-error:0.139#011validation-error:0.1805
# [22:52:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [48]#011train-error:0.137467#011validation-error:0.1781
# [22:52:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [49]#011train-error:0.136067#011validation-error:0.1781
# [22:52:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [50]#011train-error:0.135733#011validation-error:0.178
# [22:52:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [51]#011train-error:0.1346#011validation-error:0.1763
# [22:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [52]#011train-error:0.134067#011validation-error:0.1756
# [22:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [53]#011train-error:0.1336#011validation-error:0.1747
# [22:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [54]#011train-error:0.133267#011validation-error:0.1739
# [22:52:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [55]#011train-error:0.132467#011validation-error:0.1729
# [22:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [56]#011train-error:0.131267#011validation-error:0.1721
# [22:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [57]#011train-error:0.131533#011validation-error:0.1716
# [22:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [58]#011train-error:0.129133#011validation-error:0.1694
# [22:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=5
# [59]#011train-error:0.1284#011validation-error:0.1708
# [22:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [60]#011train-error:0.1256#011validation-error:0.1688
# [22:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [61]#011train-error:0.1254#011validation-error:0.168
# [22:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=5
# [62]#011train-error:0.124333#011validation-error:0.1683
# [22:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [63]#011train-error:0.1244#011validation-error:0.1684
# [22:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [64]#011train-error:0.1226#011validation-error:0.1686
# [22:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [65]#011train-error:0.121467#011validation-error:0.169
# [22:52:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [66]#011train-error:0.121733#011validation-error:0.1688
# [22:52:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [67]#011train-error:0.1222#011validation-error:0.1679
# [22:52:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [68]#011train-error:0.120467#011validation-error:0.1671
# [22:52:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [69]#011train-error:0.121#011validation-error:0.1666
# [22:52:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [70]#011train-error:0.120333#011validation-error:0.1665
# [22:52:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [71]#011train-error:0.119867#011validation-error:0.1657
# [22:52:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [72]#011train-error:0.119667#011validation-error:0.1648
# [22:52:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [73]#011train-error:0.119467#011validation-error:0.1638
# [22:52:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [74]#011train-error:0.119067#011validation-error:0.1646
# [22:52:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [75]#011train-error:0.118533#011validation-error:0.1648
# [22:53:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [76]#011train-error:0.117#011validation-error:0.1628
# [22:53:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [77]#011train-error:0.115733#011validation-error:0.1629
# [22:53:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [78]#011train-error:0.113933#011validation-error:0.1611
# [22:53:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [79]#011train-error:0.113#011validation-error:0.1617
# [22:53:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [80]#011train-error:0.112733#011validation-error:0.1605
# [22:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [81]#011train-error:0.112267#011validation-error:0.1613
# [22:53:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [82]#011train-error:0.111467#011validation-error:0.1604
# [22:53:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [83]#011train-error:0.111733#011validation-error:0.1594
# [22:53:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [84]#011train-error:0.110467#011validation-error:0.159
# [22:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=5
# [85]#011train-error:0.1082#011validation-error:0.1594
# [22:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [86]#011train-error:0.107733#011validation-error:0.1588
# [22:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [87]#011train-error:0.107533#011validation-error:0.1592
# [22:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=5
# [88]#011train-error:0.1072#011validation-error:0.1592
# [22:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 16 pruned nodes, max_depth=5
# [89]#011train-error:0.106467#011validation-error:0.1585
# [22:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [90]#011train-error:0.105867#011validation-error:0.1578
# [22:53:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [91]#011train-error:0.106067#011validation-error:0.159
# [22:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [92]#011train-error:0.106133#011validation-error:0.1577
# [22:53:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [93]#011train-error:0.106067#011validation-error:0.1586
# [22:53:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [94]#011train-error:0.106#011validation-error:0.1582
# [22:53:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 18 pruned nodes, max_depth=5
# [95]#011train-error:0.104467#011validation-error:0.1573
# [22:53:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [96]#011train-error:0.1036#011validation-error:0.1581
# [22:53:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [97]#011train-error:0.103867#011validation-error:0.1569
# [22:53:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [98]#011train-error:0.1034#011validation-error:0.1568
# [22:53:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [99]#011train-error:0.102267#011validation-error:0.157
# [22:53:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [100]#011train-error:0.102#011validation-error:0.157
# [22:53:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=5
# [101]#011train-error:0.1012#011validation-error:0.1568
# [22:53:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [102]#011train-error:0.1014#011validation-error:0.1564
# [22:53:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [103]#011train-error:0.100867#011validation-error:0.1561
# [22:53:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [104]#011train-error:0.099733#011validation-error:0.1551
# [22:53:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [105]#011train-error:0.0992#011validation-error:0.1548
# [22:53:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [106]#011train-error:0.0992#011validation-error:0.155
# [22:53:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [107]#011train-error:0.0986#011validation-error:0.1552
# [22:53:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=5
# [108]#011train-error:0.098133#011validation-error:0.1548
# [22:53:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [109]#011train-error:0.098#011validation-error:0.1538
# [22:53:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [110]#011train-error:0.098#011validation-error:0.154
# [22:53:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [111]#011train-error:0.097467#011validation-error:0.1547
# [22:53:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [112]#011train-error:0.0968#011validation-error:0.154
# [22:53:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [113]#011train-error:0.096267#011validation-error:0.155
# [22:53:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [114]#011train-error:0.0962#011validation-error:0.1542
# [22:53:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [115]#011train-error:0.095467#011validation-error:0.1542
# [22:53:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=5
# [116]#011train-error:0.095333#011validation-error:0.153
# [22:53:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [117]#011train-error:0.095#011validation-error:0.1527
# [22:53:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [118]#011train-error:0.094067#011validation-error:0.1521
# [22:53:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [119]#011train-error:0.093467#011validation-error:0.1517
# [22:53:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [120]#011train-error:0.093467#011validation-error:0.1526
# [22:53:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [121]#011train-error:0.092867#011validation-error:0.1517
# [22:53:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [122]#011train-error:0.092867#011validation-error:0.1512
# [22:53:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [123]#011train-error:0.092467#011validation-error:0.1512
# [22:54:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [124]#011train-error:0.092#011validation-error:0.1502
# [22:54:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [125]#011train-error:0.0922#011validation-error:0.1503
# [22:54:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [126]#011train-error:0.091467#011validation-error:0.1501
# [22:54:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [127]#011train-error:0.090867#011validation-error:0.1494
# [22:54:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [128]#011train-error:0.0898#011validation-error:0.1497
# [22:54:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [129]#011train-error:0.089733#011validation-error:0.1498
# [22:54:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [130]#011train-error:0.089867#011validation-error:0.1488
# [22:54:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [131]#011train-error:0.088667#011validation-error:0.1493
# [22:54:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 16 pruned nodes, max_depth=5
# [132]#011train-error:0.088333#011validation-error:0.1486
# [22:54:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [133]#011train-error:0.0882#011validation-error:0.1483
# [22:54:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [134]#011train-error:0.088067#011validation-error:0.1475
# [22:54:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [135]#011train-error:0.0876#011validation-error:0.1479
# [22:54:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [136]#011train-error:0.087#011validation-error:0.1471
# [22:54:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [137]#011train-error:0.086533#011validation-error:0.1475
# [22:54:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [138]#011train-error:0.086533#011validation-error:0.147
# [22:54:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [139]#011train-error:0.086533#011validation-error:0.1467
# [22:54:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [140]#011train-error:0.0866#011validation-error:0.1468
# [22:54:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [141]#011train-error:0.085333#011validation-error:0.146
# [22:54:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [142]#011train-error:0.085533#011validation-error:0.1452
# [22:54:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [143]#011train-error:0.0852#011validation-error:0.146
# [22:54:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [144]#011train-error:0.084133#011validation-error:0.1454
# [22:54:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [145]#011train-error:0.084333#011validation-error:0.1456
# [22:54:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [146]#011train-error:0.084#011validation-error:0.145
# [22:54:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [147]#011train-error:0.083733#011validation-error:0.1457
# [22:54:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [148]#011train-error:0.0834#011validation-error:0.1453
# [22:54:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [149]#011train-error:0.0832#011validation-error:0.1451
# [22:54:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [150]#011train-error:0.0828#011validation-error:0.145
# [22:54:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [151]#011train-error:0.0822#011validation-error:0.1446
# [22:54:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [152]#011train-error:0.081933#011validation-error:0.1437
# [22:54:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [153]#011train-error:0.081733#011validation-error:0.1448
# [22:54:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [154]#011train-error:0.0814#011validation-error:0.1447
# [22:54:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [155]#011train-error:0.081067#011validation-error:0.1446
# [22:54:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [156]#011train-error:0.0802#011validation-error:0.1439
# [22:54:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [157]#011train-error:0.080533#011validation-error:0.1442
# [22:54:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [158]#011train-error:0.080067#011validation-error:0.144
# [22:54:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [159]#011train-error:0.079933#011validation-error:0.1442
# [22:54:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [160]#011train-error:0.079733#011validation-error:0.1443
# [22:54:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [161]#011train-error:0.078067#011validation-error:0.1439
# [22:54:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 18 pruned nodes, max_depth=5
# [162]#011train-error:0.078133#011validation-error:0.1436
# [22:54:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [163]#011train-error:0.078067#011validation-error:0.1438
# [22:54:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [164]#011train-error:0.077533#011validation-error:0.143
# [22:54:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [165]#011train-error:0.077067#011validation-error:0.1434
# [22:54:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [166]#011train-error:0.077333#011validation-error:0.1431
# [22:54:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [167]#011train-error:0.076933#011validation-error:0.1428
# [22:54:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [168]#011train-error:0.076133#011validation-error:0.1423
# [22:54:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [169]#011train-error:0.075733#011validation-error:0.1419
# [22:54:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [170]#011train-error:0.075733#011validation-error:0.1422
# [22:55:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [171]#011train-error:0.0758#011validation-error:0.1418
# [22:55:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [172]#011train-error:0.075867#011validation-error:0.142
# [22:55:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [173]#011train-error:0.075267#011validation-error:0.1415
# [22:55:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [174]#011train-error:0.075133#011validation-error:0.1416
# [22:55:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [175]#011train-error:0.0752#011validation-error:0.1412
# [22:55:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [176]#011train-error:0.0748#011validation-error:0.1417
# [22:55:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [177]#011train-error:0.074667#011validation-error:0.1411
# [22:55:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [178]#011train-error:0.074333#011validation-error:0.1415
# [22:55:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [179]#011train-error:0.0742#011validation-error:0.1416
# [22:55:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=5
# [180]#011train-error:0.074267#011validation-error:0.142
# [22:55:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [181]#011train-error:0.073467#011validation-error:0.1419
# [22:55:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [182]#011train-error:0.0736#011validation-error:0.1417
# [22:55:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [183]#011train-error:0.072867#011validation-error:0.1415
# [22:55:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [184]#011train-error:0.073133#011validation-error:0.141
# [22:55:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [185]#011train-error:0.072667#011validation-error:0.1415
# [22:55:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [186]#011train-error:0.072533#011validation-error:0.1411
# [22:55:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [187]#011train-error:0.071867#011validation-error:0.141
# [22:55:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [188]#011train-error:0.071667#011validation-error:0.1408
# [22:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [189]#011train-error:0.071533#011validation-error:0.1409
# [22:55:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [190]#011train-error:0.0712#011validation-error:0.1408
# [22:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [191]#011train-error:0.071267#011validation-error:0.1401
# [22:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [192]#011train-error:0.0712#011validation-error:0.1406
# [22:55:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [193]#011train-error:0.071267#011validation-error:0.1402
# [22:55:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [194]#011train-error:0.0712#011validation-error:0.1393
# [22:55:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [195]#011train-error:0.070667#011validation-error:0.1392
# [22:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [196]#011train-error:0.070333#011validation-error:0.1391
# [22:55:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [197]#011train-error:0.070067#011validation-error:0.1395
# [22:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [198]#011train-error:0.0704#011validation-error:0.1389
# [22:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=5
# [199]#011train-error:0.069867#011validation-error:0.1387
# [22:55:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [200]#011train-error:0.07#011validation-error:0.1383
# [22:55:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=5
# [201]#011train-error:0.069333#011validation-error:0.1389
# [22:55:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [202]#011train-error:0.069#011validation-error:0.1386
# [22:55:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [203]#011train-error:0.068733#011validation-error:0.1385
# [22:55:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [204]#011train-error:0.068467#011validation-error:0.1381
# [22:55:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [205]#011train-error:0.0686#011validation-error:0.1385
# [22:55:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [206]#011train-error:0.068667#011validation-error:0.1379
# [22:55:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [207]#011train-error:0.068267#011validation-error:0.1375
# [22:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [208]#011train-error:0.068867#011validation-error:0.1375
# [22:55:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [209]#011train-error:0.0686#011validation-error:0.1374
# [22:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [210]#011train-error:0.0686#011validation-error:0.1378
# [22:55:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [211]#011train-error:0.068733#011validation-error:0.1382
# [22:55:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [212]#011train-error:0.068133#011validation-error:0.1378
# [22:55:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [213]#011train-error:0.067867#011validation-error:0.1383
# [22:55:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [214]#011train-error:0.0682#011validation-error:0.1376
# [22:55:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [215]#011train-error:0.067867#011validation-error:0.1372
# [22:55:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [216]#011train-error:0.067533#011validation-error:0.1373
# [22:55:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [217]#011train-error:0.067733#011validation-error:0.1369
# [22:55:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [218]#011train-error:0.067467#011validation-error:0.1368
# [22:56:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [219]#011train-error:0.067267#011validation-error:0.137
# [22:56:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [220]#011train-error:0.066933#011validation-error:0.1371
# [22:56:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [221]#011train-error:0.067067#011validation-error:0.1367
# [22:56:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [222]#011train-error:0.067#011validation-error:0.1369
# [22:56:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [223]#011train-error:0.066867#011validation-error:0.1369
# [22:56:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [224]#011train-error:0.066333#011validation-error:0.1364
# [22:56:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [225]#011train-error:0.066667#011validation-error:0.1364
# [22:56:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 18 pruned nodes, max_depth=5
# [226]#011train-error:0.0666#011validation-error:0.1372
# [22:56:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [227]#011train-error:0.0658#011validation-error:0.1366
# [22:56:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [228]#011train-error:0.065267#011validation-error:0.1367
# [22:56:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [229]#011train-error:0.065733#011validation-error:0.1372
# [22:56:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [230]#011train-error:0.065467#011validation-error:0.1368
# [22:56:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [231]#011train-error:0.0648#011validation-error:0.1366
# [22:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [232]#011train-error:0.0644#011validation-error:0.1365
# [22:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [233]#011train-error:0.0642#011validation-error:0.1362
# [22:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [234]#011train-error:0.0644#011validation-error:0.1356
# [22:56:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [235]#011train-error:0.064067#011validation-error:0.1352
# [22:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [236]#011train-error:0.064067#011validation-error:0.1351
# [22:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [237]#011train-error:0.0638#011validation-error:0.1358
# [22:56:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [238]#011train-error:0.062933#011validation-error:0.1355
# [22:56:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [239]#011train-error:0.062467#011validation-error:0.1362
# [22:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [240]#011train-error:0.062667#011validation-error:0.1361
# [22:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [241]#011train-error:0.062267#011validation-error:0.1363
# [22:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [242]#011train-error:0.062267#011validation-error:0.1364
# [22:56:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [243]#011train-error:0.062267#011validation-error:0.1372
# [22:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=5
# [244]#011train-error:0.062133#011validation-error:0.1371
# [22:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [245]#011train-error:0.0624#011validation-error:0.1373
# [22:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [246]#011train-error:0.0622#011validation-error:0.1373
# Stopping. Best iteration:
# [236]#011train-error:0.064067#011validation-error:0.1351
#
# Training seconds: 362
# Billable seconds: 362

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb,
                                               objective_metric_name = 'validation:rmse',
                                               objective_type = 'Minimize',
                                               max_jobs = 6,
                                               max_parallel_jobs = 3,
                                               hyperparameter_ranges = {
                                                   'max_depth': IntegerParameter(3, 12),
                                                   'eta' : ContinuousParameter(0.05, 0.5),
                                                   'min_child_weight': IntegerParameter(2, 8),
                                                   'subsample': ContinuousParameter(0.5, 0.9),
                                                   'gamma': ContinuousParameter(0, 10)
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ........................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2020-04-20 00:11:40 Starting - Preparing the instances for training
# 2020-04-20 00:11:40 Downloading - Downloading input data
# 2020-04-20 00:11:40 Training - Training image download completed. Training in progress.
# 2020-04-20 00:11:40 Uploading - Uploading generated training model
# 2020-04-20 00:11:40 Completed - Training job completedArguments: train
# [2020-04-20:00:11:19:INFO] Running standalone xgboost training.
# [2020-04-20:00:11:19:INFO] Setting up HPO optimized metric to be : rmse
# [2020-04-20:00:11:19:INFO] File size need to be processed in the node: 9.14mb. Available memory size in the node: 8500.41mb
# [2020-04-20:00:11:19:INFO] Determined delimiter of CSV input is ','
# [00:11:19] S3DistributionType set as FullyReplicated
# [00:11:19] 15000x178 matrix with 2670000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-04-20:00:11:19:INFO] Determined delimiter of CSV input is ','
# [00:11:19] S3DistributionType set as FullyReplicated
# [00:11:19] 10000x178 matrix with 1780000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 12 pruned nodes, max_depth=6
# [0]#011train-rmse:0.496757#011validation-rmse:0.497298
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 6 pruned nodes, max_depth=6
# [1]#011train-rmse:0.493649#011validation-rmse:0.494965
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 8 pruned nodes, max_depth=6
# [2]#011train-rmse:0.490748#011validation-rmse:0.492902
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 12 pruned nodes, max_depth=6
# [3]#011train-rmse:0.48817#011validation-rmse:0.491004
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 6 pruned nodes, max_depth=6
# [4]#011train-rmse:0.485761#011validation-rmse:0.489415
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 12 pruned nodes, max_depth=6
# [5]#011train-rmse:0.483474#011validation-rmse:0.487908
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 8 pruned nodes, max_depth=6
# [6]#011train-rmse:0.481535#011validation-rmse:0.486553
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 10 pruned nodes, max_depth=6
# [7]#011train-rmse:0.479794#011validation-rmse:0.485403
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 6 pruned nodes, max_depth=6
# [8]#011train-rmse:0.47795#011validation-rmse:0.484218
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 4 pruned nodes, max_depth=6
# [9]#011train-rmse:0.476306#011validation-rmse:0.483304
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 10 pruned nodes, max_depth=6
# [10]#011train-rmse:0.474802#011validation-rmse:0.482424
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 10 pruned nodes, max_depth=6
# [11]#011train-rmse:0.473269#011validation-rmse:0.481422
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 10 pruned nodes, max_depth=6
# [12]#011train-rmse:0.471896#011validation-rmse:0.480645
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 10 pruned nodes, max_depth=6
# [13]#011train-rmse:0.470584#011validation-rmse:0.479799
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 8 pruned nodes, max_depth=6
# [14]#011train-rmse:0.46941#011validation-rmse:0.479071
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 6 pruned nodes, max_depth=6
# [15]#011train-rmse:0.468137#011validation-rmse:0.478239
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 14 pruned nodes, max_depth=6
# [16]#011train-rmse:0.467078#011validation-rmse:0.477734
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 4 pruned nodes, max_depth=6
# [17]#011train-rmse:0.46574#011validation-rmse:0.477154
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=6
# [18]#011train-rmse:0.464264#011validation-rmse:0.476483
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 12 pruned nodes, max_depth=6
# [19]#011train-rmse:0.462944#011validation-rmse:0.475952
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 12 pruned nodes, max_depth=6
# [20]#011train-rmse:0.461723#011validation-rmse:0.475309
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 10 pruned nodes, max_depth=6
# [21]#011train-rmse:0.460866#011validation-rmse:0.474743
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 12 pruned nodes, max_depth=6
# [22]#011train-rmse:0.460216#011validation-rmse:0.47442
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=6
# [23]#011train-rmse:0.459162#011validation-rmse:0.473982
# [00:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 2 pruned nodes, max_depth=6
# [24]#011train-rmse:0.457944#011validation-rmse:0.473531
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 12 pruned nodes, max_depth=6
# [25]#011train-rmse:0.45668#011validation-rmse:0.473021
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 10 pruned nodes, max_depth=6
# [26]#011train-rmse:0.455709#011validation-rmse:0.472478
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 8 pruned nodes, max_depth=6
# [27]#011train-rmse:0.454745#011validation-rmse:0.472174
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 10 pruned nodes, max_depth=6
# [28]#011train-rmse:0.453945#011validation-rmse:0.471731
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 10 pruned nodes, max_depth=6
# [29]#011train-rmse:0.452979#011validation-rmse:0.471354
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 12 pruned nodes, max_depth=6
# [30]#011train-rmse:0.451777#011validation-rmse:0.470942
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=6
# [31]#011train-rmse:0.450734#011validation-rmse:0.470426
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=6
# [32]#011train-rmse:0.44973#011validation-rmse:0.470013
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 12 pruned nodes, max_depth=6
# [33]#011train-rmse:0.449078#011validation-rmse:0.469672
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 12 pruned nodes, max_depth=6
# [34]#011train-rmse:0.448323#011validation-rmse:0.469287
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 6 pruned nodes, max_depth=6
# [35]#011train-rmse:0.447467#011validation-rmse:0.469049
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 4 pruned nodes, max_depth=6
# [36]#011train-rmse:0.446695#011validation-rmse:0.468665
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=6
# [37]#011train-rmse:0.446237#011validation-rmse:0.468338
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=6
# [38]#011train-rmse:0.445651#011validation-rmse:0.46817
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 12 pruned nodes, max_depth=6
# [39]#011train-rmse:0.444898#011validation-rmse:0.467988
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 18 pruned nodes, max_depth=6
# [40]#011train-rmse:0.444005#011validation-rmse:0.467714
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=6
# [41]#011train-rmse:0.443459#011validation-rmse:0.46752
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=6
# [42]#011train-rmse:0.442907#011validation-rmse:0.467347
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 6 pruned nodes, max_depth=6
# [43]#011train-rmse:0.441924#011validation-rmse:0.467074
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 12 pruned nodes, max_depth=6
# [44]#011train-rmse:0.44109#011validation-rmse:0.466822
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 4 pruned nodes, max_depth=6
# [45]#011train-rmse:0.44024#011validation-rmse:0.466674
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 8 pruned nodes, max_depth=6
# [46]#011train-rmse:0.439218#011validation-rmse:0.466494
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=6
# [47]#011train-rmse:0.438267#011validation-rmse:0.466191
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 8 pruned nodes, max_depth=6
# [48]#011train-rmse:0.437278#011validation-rmse:0.465879
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 8 pruned nodes, max_depth=6
# [49]#011train-rmse:0.43622#011validation-rmse:0.465707
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 10 pruned nodes, max_depth=6
# [50]#011train-rmse:0.435289#011validation-rmse:0.465432
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 16 pruned nodes, max_depth=6
# [51]#011train-rmse:0.434818#011validation-rmse:0.465288
# [00:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 14 pruned nodes, max_depth=6
# [52]#011train-rmse:0.433916#011validation-rmse:0.465068
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 10 pruned nodes, max_depth=6
# [53]#011train-rmse:0.433158#011validation-rmse:0.465004
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=6
# [54]#011train-rmse:0.432735#011validation-rmse:0.464908
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 10 pruned nodes, max_depth=6
# [55]#011train-rmse:0.431939#011validation-rmse:0.46474
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 10 pruned nodes, max_depth=6
# [56]#011train-rmse:0.431353#011validation-rmse:0.464644
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=6
# [57]#011train-rmse:0.430672#011validation-rmse:0.464405
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 12 pruned nodes, max_depth=6
# [58]#011train-rmse:0.429872#011validation-rmse:0.464148
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=6
# [59]#011train-rmse:0.429014#011validation-rmse:0.463958
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 10 pruned nodes, max_depth=6
# [60]#011train-rmse:0.428356#011validation-rmse:0.463605
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 10 pruned nodes, max_depth=6
# [61]#011train-rmse:0.427396#011validation-rmse:0.463433
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 16 pruned nodes, max_depth=6
# [62]#011train-rmse:0.426718#011validation-rmse:0.463271
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 12 pruned nodes, max_depth=6
# [63]#011train-rmse:0.426158#011validation-rmse:0.463088
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 8 pruned nodes, max_depth=6
# [64]#011train-rmse:0.425488#011validation-rmse:0.463035
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 14 pruned nodes, max_depth=6
# [65]#011train-rmse:0.424666#011validation-rmse:0.462821
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 14 pruned nodes, max_depth=6
# [66]#011train-rmse:0.424116#011validation-rmse:0.462638
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 4 pruned nodes, max_depth=6
# [67]#011train-rmse:0.423275#011validation-rmse:0.462487
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 8 pruned nodes, max_depth=6
# [68]#011train-rmse:0.422955#011validation-rmse:0.462422
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=6
# [69]#011train-rmse:0.422512#011validation-rmse:0.462378
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=6
# [70]#011train-rmse:0.422108#011validation-rmse:0.462303
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 10 pruned nodes, max_depth=6
# [71]#011train-rmse:0.421614#011validation-rmse:0.462177
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 16 pruned nodes, max_depth=6
# [72]#011train-rmse:0.420727#011validation-rmse:0.461982
# [00:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 10 pruned nodes, max_depth=6
# [73]#011train-rmse:0.420078#011validation-rmse:0.461901
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=6
# [74]#011train-rmse:0.41983#011validation-rmse:0.461879
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 4 pruned nodes, max_depth=6
# [75]#011train-rmse:0.41901#011validation-rmse:0.461966
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 24 pruned nodes, max_depth=6
# [76]#011train-rmse:0.418476#011validation-rmse:0.46191
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [77]#011train-rmse:0.418185#011validation-rmse:0.461872
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=6
# [78]#011train-rmse:0.417946#011validation-rmse:0.461797
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 10 pruned nodes, max_depth=6
# [79]#011train-rmse:0.417071#011validation-rmse:0.461612
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 8 pruned nodes, max_depth=6
# [80]#011train-rmse:0.41636#011validation-rmse:0.461552
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 12 pruned nodes, max_depth=6
# [81]#011train-rmse:0.415689#011validation-rmse:0.461414
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [82]#011train-rmse:0.415506#011validation-rmse:0.461314
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 10 pruned nodes, max_depth=6
# [83]#011train-rmse:0.41502#011validation-rmse:0.461234
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 24 pruned nodes, max_depth=6
# [84]#011train-rmse:0.41466#011validation-rmse:0.46111
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 12 pruned nodes, max_depth=6
# [85]#011train-rmse:0.414357#011validation-rmse:0.461001
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 8 pruned nodes, max_depth=6
# [86]#011train-rmse:0.413558#011validation-rmse:0.461024
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=6
# [87]#011train-rmse:0.413155#011validation-rmse:0.460917
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=6
# [88]#011train-rmse:0.412449#011validation-rmse:0.46074
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 12 pruned nodes, max_depth=6
# [89]#011train-rmse:0.411985#011validation-rmse:0.460645
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 10 pruned nodes, max_depth=6
# [90]#011train-rmse:0.411599#011validation-rmse:0.460602
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 8 pruned nodes, max_depth=6
# [91]#011train-rmse:0.411088#011validation-rmse:0.46053
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 14 pruned nodes, max_depth=6
# [92]#011train-rmse:0.410754#011validation-rmse:0.46048
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 12 pruned nodes, max_depth=6
# [93]#011train-rmse:0.410289#011validation-rmse:0.460471
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 16 pruned nodes, max_depth=6
# [94]#011train-rmse:0.409864#011validation-rmse:0.460463
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 12 pruned nodes, max_depth=6
# [95]#011train-rmse:0.409238#011validation-rmse:0.460534
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=6
# [96]#011train-rmse:0.408796#011validation-rmse:0.460391
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=6
# [97]#011train-rmse:0.408535#011validation-rmse:0.460414
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=6
# [98]#011train-rmse:0.40809#011validation-rmse:0.460362
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 16 pruned nodes, max_depth=6
# [99]#011train-rmse:0.407711#011validation-rmse:0.460255
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=6
# [100]#011train-rmse:0.407527#011validation-rmse:0.460217
# [00:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 6 pruned nodes, max_depth=6
# [101]#011train-rmse:0.407014#011validation-rmse:0.460052
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=6
# [102]#011train-rmse:0.406711#011validation-rmse:0.459854
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 14 pruned nodes, max_depth=6
# [103]#011train-rmse:0.406335#011validation-rmse:0.459669
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 12 pruned nodes, max_depth=6
# [104]#011train-rmse:0.405496#011validation-rmse:0.459651
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=6
# [105]#011train-rmse:0.40516#011validation-rmse:0.4596
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 6 pruned nodes, max_depth=6
# [106]#011train-rmse:0.404446#011validation-rmse:0.459397
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=6
# [107]#011train-rmse:0.404013#011validation-rmse:0.45939
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=6
# [108]#011train-rmse:0.403861#011validation-rmse:0.459375
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=6
# [109]#011train-rmse:0.403645#011validation-rmse:0.459349
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 16 pruned nodes, max_depth=6
# [110]#011train-rmse:0.403199#011validation-rmse:0.459287
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=6
# [111]#011train-rmse:0.402729#011validation-rmse:0.459208
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 18 pruned nodes, max_depth=6
# [112]#011train-rmse:0.402124#011validation-rmse:0.45913
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=6
# [113]#011train-rmse:0.401773#011validation-rmse:0.459119
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=6
# [114]#011train-rmse:0.401409#011validation-rmse:0.459161
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 6 pruned nodes, max_depth=6
# [115]#011train-rmse:0.400874#011validation-rmse:0.459109
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 24 pruned nodes, max_depth=6
# [116]#011train-rmse:0.400096#011validation-rmse:0.459108
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 8 pruned nodes, max_depth=6
# [117]#011train-rmse:0.399577#011validation-rmse:0.459
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 14 pruned nodes, max_depth=6
# [118]#011train-rmse:0.399118#011validation-rmse:0.45894
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=6
# [119]#011train-rmse:0.398887#011validation-rmse:0.458892
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=6
# [120]#011train-rmse:0.398511#011validation-rmse:0.458938
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=6
# [121]#011train-rmse:0.398258#011validation-rmse:0.458953
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 10 pruned nodes, max_depth=6
# [122]#011train-rmse:0.397618#011validation-rmse:0.458885
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=6
# [123]#011train-rmse:0.397408#011validation-rmse:0.458885
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 10 pruned nodes, max_depth=6
# [124]#011train-rmse:0.39682#011validation-rmse:0.458832
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=6
# [125]#011train-rmse:0.396607#011validation-rmse:0.458887
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 20 pruned nodes, max_depth=6
# [126]#011train-rmse:0.396156#011validation-rmse:0.458864
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 12 pruned nodes, max_depth=6
# [127]#011train-rmse:0.39569#011validation-rmse:0.458838
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=6
# [128]#011train-rmse:0.395319#011validation-rmse:0.458772
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=6
# [129]#011train-rmse:0.39516#011validation-rmse:0.458783
# [00:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=6
# [130]#011train-rmse:0.395063#011validation-rmse:0.458819
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=6
# [131]#011train-rmse:0.394857#011validation-rmse:0.458752
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 10 pruned nodes, max_depth=6
# [132]#011train-rmse:0.394394#011validation-rmse:0.458699
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 10 pruned nodes, max_depth=6
# [133]#011train-rmse:0.393866#011validation-rmse:0.458591
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=6
# [134]#011train-rmse:0.393205#011validation-rmse:0.458562
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 10 pruned nodes, max_depth=6
# [135]#011train-rmse:0.392842#011validation-rmse:0.458566
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=6
# [136]#011train-rmse:0.39253#011validation-rmse:0.458565
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [137]#011train-rmse:0.392306#011validation-rmse:0.458549
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 24 pruned nodes, max_depth=6
# [138]#011train-rmse:0.391898#011validation-rmse:0.458507
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 16 pruned nodes, max_depth=6
# [139]#011train-rmse:0.39144#011validation-rmse:0.458558
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=6
# [140]#011train-rmse:0.391103#011validation-rmse:0.458546
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=6
# [141]#011train-rmse:0.390596#011validation-rmse:0.458454
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 12 pruned nodes, max_depth=6
# [142]#011train-rmse:0.390055#011validation-rmse:0.458404
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 26 pruned nodes, max_depth=6
# [143]#011train-rmse:0.389899#011validation-rmse:0.458383
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=6
# [144]#011train-rmse:0.389629#011validation-rmse:0.458383
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [145]#011train-rmse:0.389446#011validation-rmse:0.458288
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 18 pruned nodes, max_depth=6
# [146]#011train-rmse:0.388983#011validation-rmse:0.458229
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=6
# [147]#011train-rmse:0.388831#011validation-rmse:0.4583
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=6
# [148]#011train-rmse:0.38869#011validation-rmse:0.458257
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=6
# [149]#011train-rmse:0.388518#011validation-rmse:0.458206
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 14 pruned nodes, max_depth=6
# [150]#011train-rmse:0.387913#011validation-rmse:0.458173
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 18 pruned nodes, max_depth=6
# [151]#011train-rmse:0.387441#011validation-rmse:0.458258
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=6
# [152]#011train-rmse:0.387093#011validation-rmse:0.458295
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=6
# [153]#011train-rmse:0.3867#011validation-rmse:0.458173
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 18 pruned nodes, max_depth=6
# [154]#011train-rmse:0.386231#011validation-rmse:0.458158
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 8 pruned nodes, max_depth=6
# [155]#011train-rmse:0.385857#011validation-rmse:0.458223
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 20 pruned nodes, max_depth=6
# [156]#011train-rmse:0.385285#011validation-rmse:0.458087
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 24 pruned nodes, max_depth=6
# [157]#011train-rmse:0.385069#011validation-rmse:0.458042
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 18 pruned nodes, max_depth=6
# [158]#011train-rmse:0.384581#011validation-rmse:0.458063
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 22 pruned nodes, max_depth=6
# [159]#011train-rmse:0.384266#011validation-rmse:0.458049
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 22 pruned nodes, max_depth=6
# [160]#011train-rmse:0.38403#011validation-rmse:0.458008
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 12 pruned nodes, max_depth=6
# [161]#011train-rmse:0.383683#011validation-rmse:0.458035
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 16 pruned nodes, max_depth=6
# [162]#011train-rmse:0.383066#011validation-rmse:0.457989
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 16 pruned nodes, max_depth=6
# [163]#011train-rmse:0.382706#011validation-rmse:0.45799
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 24 pruned nodes, max_depth=6
# [164]#011train-rmse:0.382363#011validation-rmse:0.457954
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 14 pruned nodes, max_depth=6
# [165]#011train-rmse:0.38198#011validation-rmse:0.457987
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 14 pruned nodes, max_depth=6
# [166]#011train-rmse:0.381625#011validation-rmse:0.45795
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 28 pruned nodes, max_depth=6
# [167]#011train-rmse:0.381249#011validation-rmse:0.458024
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=6
# [168]#011train-rmse:0.381132#011validation-rmse:0.458017
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 16 pruned nodes, max_depth=6
# [169]#011train-rmse:0.38086#011validation-rmse:0.458024
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 4 pruned nodes, max_depth=6
# [170]#011train-rmse:0.38058#011validation-rmse:0.458007
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 20 pruned nodes, max_depth=6
# [171]#011train-rmse:0.380409#011validation-rmse:0.458027
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 24 pruned nodes, max_depth=6
# [172]#011train-rmse:0.380262#011validation-rmse:0.458023
# [00:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 18 pruned nodes, max_depth=6
# [173]#011train-rmse:0.379938#011validation-rmse:0.458028
# [00:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 18 pruned nodes, max_depth=6
# [174]#011train-rmse:0.379826#011validation-rmse:0.457973
# [00:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=6
# [175]#011train-rmse:0.379471#011validation-rmse:0.458002
# [00:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 26 pruned nodes, max_depth=6
# [176]#011train-rmse:0.37906#011validation-rmse:0.458007
# Stopping. Best iteration:
# [166]#011train-rmse:0.381625#011validation-rmse:0.45795
#
# Training seconds: 76
# Billable seconds: 76

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count=1, instance_type='ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='test/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ...................

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
